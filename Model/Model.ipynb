# %%
# %%capture
from common import data, viz
import nussl

# %%
# Prepare MUSDB
#data.prepare_musdb('D:/src/Piano-Audio-Separation/Dataset/musdb/')
# Out:
# 100%|██████████| 80/80 [00:30<00:00,  2.58it/s]
# 100%|██████████| 14/14 [00:05<00:00,  2.40it/s]
# 100%|██████████| 50/50 [00:20<00:00,  2.44it/s]

# %%
stft_params = nussl.STFTParams(window_length=512, hop_length=128, window_type='sqrt_hann')
fg_path = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/train/"
train_data = data.on_the_fly(stft_params, transform=None, fg_path=fg_path, num_mixtures=1000, coherent_prob=1.0)

# %%
item = train_data[0]
viz.show_sources(item['sources'])
# Out:
# <div id=ZXUCOBQMCLJERXSIISVR class=audio-container preload=auto name=ZXUCOBQMCLJERXSIISVR><audio name='vocals' url=data:audio/wav;base64,...></audio><audio name='drums' url=data:audio/wav;base64,...></audio><audio name='bass' url=data:audio/wav;base64,...></audio><audio name='other' url=data:audio/wav;base64,...></audio></div><style>.inline{display:inline}.center{margin:0 auto}.float-left,.audio-container ul.tracks>li ul,.audio-container .track-name{display:inline;float:left}.float-right{display:inline;float:right}.hidden{display:none}.display-block,.bkg-list li a,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container ul.tracks>li{display:block}.fixed{position:fixed}.relative,.audio-container .main-control,.expandable>:first-child a{position:relative}.absolute,.audio-container .main-control ul,.audio-container .main-control .timebar-wrapper .timebar{position:absolute}.invisible{visibility:hidden}.no-overflow{overflow:hidden}.scroll{overflow:auto;scroll:auto}.inline-block-list,.control-list,.audio-container ul.tracks>li ul,.audio-container .main-control ul{margin:0;padding:0;border:0;overflow:hidden;*zoom:1}.inline-block-list li,.control-list li,.audio-container ul.tracks>li ul li,.audio-container .main-control ul li{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap;padding:0}.inline-block-list-item,.control-list>li,.audio-container ul.tracks>li ul>li,.audio-container .main-control ul>li,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap}@-webkit-keyframes open-sub-expand{0%{opacity:0;max-height:0}100%{opacity:1;max-height:3000px;display:block}}@-moz-keyframes open-sub-expand{from{opacity:0;max-height:0;display:none}to{opacity:1;max-height:3000px;display:block}}@-webkit-keyframes close-sub-expand{0%{opacity:1;max-height:3000px;display:block}100%{opacity:0;max-height:0;display:none}}@-moz-keyframes close-sub-expand{from{opacity:1;max-height:3000px;display:block}to{opacity:0;max-height:0;display:none}}.t-left,.bkg-list li a{text-align:left}.t-right{text-align:right}.t-center{text-align:center;vertical-align:middle}.t-justify{text-align:justify}.t-hide,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container .loader,.audio-container .loading-link,.audio-container .status{text-indent:-3333px;overflow:hidden}.t-caps,.button{text-transform:uppercase}.t-lower{text-transform:lowercase}.t-no-select{-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-o-user-select:none;user-select:none}.no-background{background:none !important}body.high-graphics .css-transition-all,body.high-graphics .bkg-link,body.high-graphics .bkg-list li a,.bkg-list li body.high-graphics a,body.high-graphics .button,body.high-graphics .control-list>li>a,body.high-graphics .audio-container ul.tracks>li ul>li>a,.audio-container ul.tracks>li body.high-graphics ul>li>a,body.high-graphics .audio-container .main-control ul>li>a,.audio-container .main-control body.high-graphics ul>li>a,body.high-graphics .audio-container .tracks,.audio-container body.high-graphics .tracks,body.high-graphics .audio-container .main-control,.audio-container body.high-graphics .main-control,body.high-graphics .audio-container .loading-link,.audio-container body.high-graphics .loading-link,body.high-graphics .basic-expandable .icon-expand,.basic-expan ...

# %%
from nussl.datasets import transforms as nussl_tfm

item = train_data[0]
sum_sources = nussl_tfm.SumSources([['bass', 'drums', 'other']])
item = sum_sources(item)
viz.show_sources(item['sources'])
# Out:
# <div id=DCZKETBWDYZEBAMOOBHF class=audio-container preload=auto name=DCZKETBWDYZEBAMOOBHF><audio name='vocals' url=data:audio/wav;base64,...></audio><audio name='bass+drums+other' url=data:audio/wav;base64,...></audio></div><style>.inline{display:inline}.center{margin:0 auto}.float-left,.audio-container ul.tracks>li ul,.audio-container .track-name{display:inline;float:left}.float-right{display:inline;float:right}.hidden{display:none}.display-block,.bkg-list li a,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container ul.tracks>li{display:block}.fixed{position:fixed}.relative,.audio-container .main-control,.expandable>:first-child a{position:relative}.absolute,.audio-container .main-control ul,.audio-container .main-control .timebar-wrapper .timebar{position:absolute}.invisible{visibility:hidden}.no-overflow{overflow:hidden}.scroll{overflow:auto;scroll:auto}.inline-block-list,.control-list,.audio-container ul.tracks>li ul,.audio-container .main-control ul{margin:0;padding:0;border:0;overflow:hidden;*zoom:1}.inline-block-list li,.control-list li,.audio-container ul.tracks>li ul li,.audio-container .main-control ul li{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap;padding:0}.inline-block-list-item,.control-list>li,.audio-container ul.tracks>li ul>li,.audio-container .main-control ul>li,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap}@-webkit-keyframes open-sub-expand{0%{opacity:0;max-height:0}100%{opacity:1;max-height:3000px;display:block}}@-moz-keyframes open-sub-expand{from{opacity:0;max-height:0;display:none}to{opacity:1;max-height:3000px;display:block}}@-webkit-keyframes close-sub-expand{0%{opacity:1;max-height:3000px;display:block}100%{opacity:0;max-height:0;display:none}}@-moz-keyframes close-sub-expand{from{opacity:1;max-height:3000px;display:block}to{opacity:0;max-height:0;display:none}}.t-left,.bkg-list li a{text-align:left}.t-right{text-align:right}.t-center{text-align:center;vertical-align:middle}.t-justify{text-align:justify}.t-hide,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container .loader,.audio-container .loading-link,.audio-container .status{text-indent:-3333px;overflow:hidden}.t-caps,.button{text-transform:uppercase}.t-lower{text-transform:lowercase}.t-no-select{-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-o-user-select:none;user-select:none}.no-background{background:none !important}body.high-graphics .css-transition-all,body.high-graphics .bkg-link,body.high-graphics .bkg-list li a,.bkg-list li body.high-graphics a,body.high-graphics .button,body.high-graphics .control-list>li>a,body.high-graphics .audio-container ul.tracks>li ul>li>a,.audio-container ul.tracks>li body.high-graphics ul>li>a,body.high-graphics .audio-container .main-control ul>li>a,.audio-container .main-control body.high-graphics ul>li>a,body.high-graphics .audio-container .tracks,.audio-container body.high-graphics .tracks,body.high-graphics .audio-container .main-control,.audio-container body.high-graphics .main-control,body.high-graphics .audio-container .loading-link,.audio-container body.high-graphics .loading-link,body.high-graphics .basic-expandable .icon-expand,.basic-expandable body.high-graphics .icon-expand,body.high-graphics .expandable .icon-expand,.expandable body.high- ...

# %%
msa = nussl_tfm.MagnitudeSpectrumApproximation()
item = msa(item)

print(item.keys())
# Out:
# dict_keys(['mix', 'sources', 'metadata', 'mix_magnitude', 'ideal_binary_mask', 'source_magnitudes'])

# %%
print(item['source_magnitudes'].shape, item['mix_magnitude'].shape, item['ideal_binary_mask'].shape)
# Out:
# (257, 1724, 1, 2) (257, 1724, 1) (257, 1724, 1, 2)

# %%
import matplotlib.pyplot as plt
plt.imshow(item['source_magnitudes'][..., 1][..., 0], aspect='auto', origin='lower')
plt.title('Magnitude spectrogram of piano source')
plt.xlabel('Time frame')
plt.ylabel('Frequency bin')
plt.show()

# %%
index_sources = nussl_tfm.IndexSources('source_magnitudes', 1)
item = index_sources(item)

# %%
import matplotlib.pyplot as plt
plt.imshow(item['source_magnitudes'][..., 0, 0], aspect='auto', origin='lower')
plt.title('Magnitude spectrogram of vocals source')
plt.xlabel('Time frame')
plt.ylabel('Frequency bin')
plt.show()

print(item['source_magnitudes'].shape, item['mix_magnitude'].shape, item['ideal_binary_mask'].shape)
# Out:
# (257, 1724, 1, 1) (257, 1724, 1) (257, 1724, 1, 2)

# %%
to_separation_model = nussl_tfm.ToSeparationModel()
item = to_separation_model(item)

# %%
print(item.keys())
# Out:
# dict_keys(['mix_magnitude', 'ideal_binary_mask', 'source_magnitudes'])

# %%
tfm = nussl_tfm.Compose([
    nussl_tfm.SumSources([['bass', 'drums', 'other']]),
    nussl_tfm.MagnitudeSpectrumApproximation(),
    nussl_tfm.IndexSources('source_magnitudes', 1),
    nussl_tfm.ToSeparationModel(),
])

item = train_data[0]
print("Before transforms")
for key in item:
    print(key, type(item[key]))
print("\nAfter transforms")
item = tfm(item)
for key in item:
    print(key, type(item[key]))
# Out:
# Before transforms
# mix <class 'nussl.core.audio_signal.AudioSignal'>
# sources <class 'dict'>
# metadata <class 'dict'>
#
# After transforms
# mix_magnitude <class 'torch.Tensor'>
# ideal_binary_mask <class 'torch.Tensor'>
# source_magnitudes <class 'torch.Tensor'>

# %%
fg_path = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/train/"
train_data = data.on_the_fly(stft_params, transform=tfm, fg_path=fg_path, num_mixtures=1000, coherent_prob=1.0)

item = train_data[0]
print("Item from train data")
for key in item:
    print(key, type(item[key]))

#fg_path = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/valid/"
#val_data = data.on_the_fly(stft_params, transform=tfm, fg_path=fg_path, num_mixtures=500)

test_tfm = nussl_tfm.Compose([
    nussl_tfm.SumSources([['bass', 'drums', 'other']]),
])

#fg_path = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/test/"
#test_data = data.on_the_fly(stft_params, transform=test_tfm, fg_path=fg_path, num_mixtures=100)
# Out:
# Item from train data
# index <class 'int'>
# mix_magnitude <class 'torch.Tensor'>
# ideal_binary_mask <class 'torch.Tensor'>
# source_magnitudes <class 'torch.Tensor'>

# %% [markdown]
# # Build

# %%
from nussl.ml.networks.modules import AmplitudeToDB, BatchNorm, RecurrentStack, Embedding
from torch import nn
import torch

class MaskInference(nn.Module):
    def __init__(self, num_features, num_audio_channels, hidden_size,
                 num_layers, bidirectional, dropout, num_sources, 
                activation='sigmoid'):
        super().__init__()
        
        self.amplitude_to_db = AmplitudeToDB()
        self.input_normalization = BatchNorm(num_features)
        self.recurrent_stack = RecurrentStack(
            num_features * num_audio_channels, hidden_size, 
            num_layers, bool(bidirectional), dropout
        )
        hidden_size = hidden_size * (int(bidirectional) + 1)
        self.embedding = Embedding(num_features, hidden_size, 
                                   num_sources, activation, 
                                   num_audio_channels)
        
    def forward(self, data):
        mix_magnitude = data # guardado para el masking
        
        data = self.amplitude_to_db(mix_magnitude)
        data = self.input_normalization(data)
        data = self.recurrent_stack(data)
        mask = self.embedding(data)
        estimates = mix_magnitude.unsqueeze(-1) * mask
        
        output = {
            'mask': mask,
            'estimates': estimates
        }
        return output
    
    # Added function
    @classmethod
    def build(cls, num_features, num_audio_channels, hidden_size, 
              num_layers, bidirectional, dropout, num_sources, 
              activation='sigmoid'):
        # Step 1. Register our model with nussl
        nussl.ml.register_module(cls)
        
        # Step 2a: Define the building blocks.
        modules = {
            'model': {
                'class': 'MaskInference',
                'args': {
                    'num_features': num_features,
                    'num_audio_channels': num_audio_channels,
                    'hidden_size': hidden_size,
                    'num_layers': num_layers,
                    'bidirectional': bidirectional,
                    'dropout': dropout,
                    'num_sources': num_sources,
                    'activation': activation
                }
            }
        }
        
        
        # Step 2b: Define the connections between input and output.
        # Here, the mix_magnitude key is the only input to the model.
        connections = [
            ['model', ['mix_magnitude']]
        ]
        
        # Step 2c. The model outputs a dictionary, which SeparationModel will
        # change the keys to model:mask, model:estimates. The lines below 
        # alias model:mask to just mask, and model:estimates to estimates.
        # This will be important later when we actually deploy our model.
        for key in ['mask', 'estimates']:
            modules[key] = {'class': 'Alias'}
            connections.append([key, f'model:{key}'])
        
        # Step 2d. There are two outputs from our SeparationModel: estimates and mask.
        # Then put it all together.
        output = ['estimates', 'mask',]
        config = {
            'name': cls.__name__,
            'modules': modules,
            'connections': connections,
            'output': output
        }
        # Step 3. Instantiate the model as a SeparationModel.
        return nussl.ml.SeparationModel(config)

nf = stft_params.window_length // 2 + 1
nac = 1
model = MaskInference.build(nf, nac, 50, 2, True, 0.3, 1, 'sigmoid')

# %%
print(model.config)
# Out:
# {'name': 'MaskInference', 'modules': {'model': {'class': 'MaskInference', 'args': {'num_features': 257, 'num_audio_channels': 1, 'hidden_size': 50, 'num_layers': 2, 'bidirectional': True, 'dropout': 0.3, 'num_sources': 1, 'activation': 'sigmoid'}, 'module_snapshot': 'No module snapshot could be found. Did you define your class in an interactive Python environment? See https://bugs.python.org/issue12920 for more details.'}, 'mask': {'class': 'Alias', 'module_snapshot': 'class Alias(nn.Module):\n    """\n    Super simple module that just passes the data through without altering it, so\n    that the output of a model can be renamed in a SeparationModel.\n    """\n    def forward(self, data):\n        return data\n', 'args': {}}, 'estimates': {'class': 'Alias', 'module_snapshot': 'class Alias(nn.Module):\n    """\n    Super simple module that just passes the data through without altering it, so\n    that the output of a model can be renamed in a SeparationModel.\n    """\n    def forward(self, data):\n        return data\n', 'args': {}}}, 'connections': [['model', ['mix_magnitude']], ['mask', 'model:mask'], ['estimates', 'model:estimates']], 'output': ['estimates', 'mask']}

# %%
print(model)
# Out:
# SeparationModel(
#   (layers): ModuleDict(
#     (model): MaskInference(
#       (amplitude_to_db): AmplitudeToDB()
#       (input_normalization): BatchNorm(
#         (batch_norm): BatchNorm1d(257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (recurrent_stack): RecurrentStack(
#         (rnn): LSTM(257, 50, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#       )
#       (embedding): Embedding(
#         (linear): Linear(in_features=100, out_features=257, bias=True)
#       )
#     )
#     (mask): Alias()
#     (estimates): Alias()
#   )
# )
# Number of parameters: 210871

# %%
model.config['modules']['model']['args']
# Out:
# {'num_features': 257,
#  'num_audio_channels': 1,
#  'hidden_size': 50,
#  'num_layers': 2,
#  'bidirectional': True,
#  'dropout': 0.3,
#  'num_sources': 1,
#  'activation': 'sigmoid'}

# %%
print(model.config['modules']['model']['module_snapshot'])
# Out:
# No module snapshot could be found. Did you define your class in an interactive Python environment? See https://bugs.python.org/issue12920 for more details.

# %%
from common.models import MaskInference

nf = stft_params.window_length // 2 + 1
nac = 1
model = MaskInference.build(nf, nac, 50, 2, True, 0.3, 1, 'sigmoid')

# %%
print(model.config['modules']['model']['module_snapshot'])
# Out:
# class MaskInference(nn.Module):
#     def __init__(self, num_features, num_audio_channels, hidden_size,
#                  num_layers, bidirectional, dropout, num_sources,
#                 activation='sigmoid'):
#         super().__init__()
#
#         self.amplitude_to_db = AmplitudeToDB()
#         self.input_normalization = BatchNorm(num_features)
#         self.recurrent_stack = RecurrentStack(
#             num_features * num_audio_channels, hidden_size,
#             num_layers, bool(bidirectional), dropout
#         )
#         hidden_size = hidden_size * (int(bidirectional) + 1)
#         self.embedding = Embedding(num_features, hidden_size,
#                                    num_sources, activation,
#                                    num_audio_channels)
#
#     def forward(self, data):
#         mix_magnitude = data # save for masking
#
#         data = self.amplitude_to_db(mix_magnitude)
#         data = self.input_normalization(data)
#         data = self.recurrent_stack(data)
#         mask = self.embedding(data)
#         estimates = mix_magnitude.unsqueeze(-1) * mask
#
#         output = {
#             'mask': mask,
#             'estimates': estimates
#         }
#         return output
#
#     # Added function
#     @staticmethod
#     @argbind.bind_to_parser()
#     def build(num_features, num_audio_channels, hidden_size,
#               num_layers, bidirectional, dropout, num_sources,
#               activation='sigmoid'):
#         # Step 1. Register our model with nussl
#         nussl.ml.register_module(MaskInference)
#
#         # Step 2a: Define the building blocks.
#         modules = {
#             'model': {
#                 'class': 'MaskInference',
#                 'args': {
#                     'num_features': num_features,
#                     'num_audio_channels': num_audio_channels,
#                     'hidden_size': hidden_size,
#                     'num_layers': num_layers,
#                     'bidirectional': bidirectional,
#                     'dropout': dropout,
#                     'num_sources': num_sources,
#                     'activation': activation
#                 }
#             }
#         }
#
#         # Step 2b: Define the connections between input and output.
#         # Here, the mix_magnitude key is the only input to the model.
#         connections = [
#             ['model', ['mix_magnitude']]
#         ]
#
#         # Step 2c. The model outputs a dictionary, which SeparationModel will
#         # change the keys to model:mask, model:estimates. The lines below
#         # alias model:mask to just mask, and model:estimates to estimates.
#         # This will be important later when we actually deploy our model.
#         for key in ['mask', 'estimates']:
#             modules[key] = {'class': 'Alias'}
#             connections.append([key, [f'model:{key}']])
#
#         # Step 2d. There are two outputs from our SeparationModel: estimates and mask.
#         # Then put it all together.
#         output = ['estimates', 'mask',]
#         config = {
#             'name': 'MaskInference',
#             'modules': modules,
#             'connections': connections,
#             'output': output
#         }
#         # Step 3. Instantiate the model as a SeparationModel.
#         return nussl.ml.SeparationModel(config)

# %%
item = train_data[0]
for key in item:
    if torch.is_tensor(item[key]):
        item[key] = item[key].float().unsqueeze(0)
output = model(item)

# %%
for key in output:
    print(key, type(output[key]), output[key].shape)
# Out:
# estimates <class 'torch.Tensor'> torch.Size([1, 1724, 257, 1, 1])
# mask <class 'torch.Tensor'> torch.Size([1, 1724, 257, 1, 1])

# %%
model.verbose = True
output = model(item)
# Out:
# ['mix_magnitude'] -> model
# 	Took inputs: (1, 1724, 257, 1)
# 	Produced 'model:mask': (1, 1724, 257, 1, 1), 'model:estimates': (1, 1724, 257, 1, 1)
# 	Statistics:
# 		model:mask
# 			min: 0.2279
# 			max: 0.7834
# 			mean: 0.5000
# 			std: 0.0663
# 		model:estimates
# 			min: 0.0000
# 			max: 0.0774
# 			mean: 0.0008
# 			std: 0.0031
# ['model:mask'] -> mask
# 	Took inputs: (1, 1724, 257, 1, 1)
# 	Produced 'mask': (1, 1724, 257, 1, 1)
# 	Statistics:
# 		mask
# 			min: 0.2279
# 			max: 0.7834
# 			mean: 0.5000
# 			std: 0.0663
# ['model:estimates'] -> estimates
# 	Took inputs: (1, 1724, 257, 1, 1)
# 	Produced 'estimates': (1, 1724, 257, 1, 1)
# 	Statistics:
# 		estimates
# 			min: 0.0000
# 			max: 0.0774
# 			mean: 0.0008
# 			std: 0.0031

# %% [markdown]
# # Training

# %%
import torch

nf = stft_params.window_length // 2 + 1
nac = 1
model = MaskInference.build(nf, nac, 50, 1, True, 0.0, 1, 'sigmoid')
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nussl.ml.train.loss.L1Loss()

def train_step(batch):
    optimizer.zero_grad()
    output = model(batch) # forward pass
    loss = loss_fn(
        output['estimates'],
        batch['source_magnitudes']
    )
    
    loss.backward() # backwards + gradient step
    optimizer.step()
    
    return loss.item() # return the loss for bookkeeping.
# Out:
# SeparationModel(
#   (layers): ModuleDict(
#     (model): MaskInference(
#       (amplitude_to_db): AmplitudeToDB()
#       (input_normalization): BatchNorm(
#         (batch_norm): BatchNorm1d(257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (recurrent_stack): RecurrentStack(
#         (rnn): LSTM(257, 50, batch_first=True, bidirectional=True)
#       )
#       (embedding): Embedding(
#         (linear): Linear(in_features=100, out_features=257, bias=True)
#       )
#     )
#     (mask): Alias()
#     (estimates): Alias()
#   )
# )
# Number of parameters: 150071

# %%
# %%capture
# Comment out the line above to see the output
# of this cell in Colab or Jupyter Notebook
import tqdm

item = train_data[0] # Because of the transforms, this produces tensors.
batch = {} # A batch of size 1, in this case. Usually we'd have more.
for key in item:
    if torch.is_tensor(item[key]):
        batch[key] = item[key].float().unsqueeze(0)
    
N_ITERATIONS = 100
loss_history = [] # For bookkeeping

pbar = tqdm.tqdm(range(N_ITERATIONS))
for _ in pbar:
    loss_val = train_step(batch)
    loss_history.append(loss_val)
    pbar.set_description(f'Loss: {loss_val:.6f}')

# %%
plt.plot(loss_history)
plt.xlabel('# of iterations')
plt.ylabel('Training loss')
plt.title('Train loss history of our model')
plt.show()

# %%
def train_step(engine, batch):
    optimizer.zero_grad()
    output = model(batch) # forward pass
    loss = loss_fn(
        output['estimates'],
        batch['source_magnitudes']
    )
    
    loss.backward() # backwards + gradient step
    optimizer.step()
    
    loss_vals = {
        'L1Loss': loss.item()
    }
    
    return loss_vals # return the loss for bookkeeping.

# %%
def val_step(engine, batch):
    with torch.no_grad():
        output = model(batch) # forward pass
    loss = loss_fn(
        output['estimates'],
        batch['source_magnitudes']
    )    
    loss_vals = {'L1Loss': loss.item()}
    return loss_vals # return the loss for bookkeeping.

# %% [markdown]
# ## Build training

# %%
import nussl
import torch
from nussl.datasets import transforms as nussl_tfm
from common.models import MaskInference
from common import utils, data
from pathlib import Path

utils.logger()
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
MAX_MIXTURES = int(1e8) # We'll set this to some impossibly high number for on the fly mixing.

stft_params = nussl.STFTParams(window_length=512, hop_length=128)

tfm = nussl_tfm.Compose([
    nussl_tfm.SumSources([['bass', 'drums', 'other']]),
    nussl_tfm.MagnitudeSpectrumApproximation(),
    nussl_tfm.IndexSources('source_magnitudes', 1),
    nussl_tfm.ToSeparationModel(),
])

train_folder = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/train"
val_folder = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/valid"

train_data = data.on_the_fly(stft_params, transform=tfm, 
    fg_path=train_folder, num_mixtures=MAX_MIXTURES, coherent_prob=1.0)
train_dataloader = torch.utils.data.DataLoader(
    train_data, num_workers=1, batch_size=10)

val_data = data.on_the_fly(stft_params, transform=tfm, 
    fg_path=val_folder, num_mixtures=10, coherent_prob=1.0)
val_dataloader = torch.utils.data.DataLoader(
    val_data, num_workers=1, batch_size=10)

nf = stft_params.window_length // 2 + 1
model = MaskInference.build(nf, 1, 50, 1, True, 0.0, 1, 'sigmoid')
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nussl.ml.train.loss.L1Loss()

def train_step(engine, batch):
    optimizer.zero_grad()
    output = model(batch) # forward pass
    loss = loss_fn(
        output['estimates'],
        batch['source_magnitudes']
    )
    
    loss.backward() # backwards + gradient step
    optimizer.step()
    
    loss_vals = {
        'L1Loss': loss.item(),
        'loss': loss.item()
    }
    
    return loss_vals

def val_step(engine, batch):
    with torch.no_grad():
        output = model(batch) # forward pass
    loss = loss_fn(
        output['estimates'],
        batch['source_magnitudes']
    )    
    loss_vals = {
        'L1Loss': loss.item(), 
        'loss': loss.item()
    }
    return loss_vals

# Create the engines
trainer, validator = nussl.ml.train.create_train_and_validation_engines(
    train_step, val_step, device=DEVICE
)

# We'll save the output relative to this notebook.
output_folder = Path('.').absolute()

# Adding handlers from nussl that print out details about model training
# run the validation step, and save the models.
nussl.ml.train.add_stdout_handler(trainer, validator)
nussl.ml.train.add_validate_and_checkpoint(output_folder, model, 
    optimizer, train_data, trainer, val_dataloader, validator)

trainer.run(
    train_dataloader, 
    epoch_length=100, 
    max_epochs=30
)
# Out:
# 05/08/2025 01:43:11 AM | engine.py:887 Engine run starting with max_epochs=30.
# 05/08/2025 01:49:05 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 01:49:20 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:14.810
# 05/08/2025 01:49:20 AM | engine.py:1018 Engine run finished. Time taken: 00:00:14.939
# 05/08/2025 01:49:23 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0001 / 0030
# - Training loss:   0.000442
# - Validation loss: 0.000428
# - Epoch took: 0:06:11.409212
# - Time since start: 0:06:11.409285
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\best.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 01:49:23 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:05:51.786
# 05/08/2025 01:54:49 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 01:55:04 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:15.218
# 05/08/2025 01:55:04 AM | engine.py:1018 Engine run finished. Time taken: 00:00:15.333
# 05/08/2025 01:55:05 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0002 / 0030
# - Training loss:   0.000406
# - Validation loss: 0.000418
# - Epoch took: 0:05:42.031443
# - Time since start: 0:11:53.441780
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\best.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 01:55:05 AM | engine.py:992 Epoch[2] Complete. Time taken: 00:05:42.032
# 05/08/2025 02:00:33 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:00:48 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:14.266
# 05/08/2025 02:00:48 AM | engine.py:1018 Engine run finished. Time taken: 00:00:14.356
# 05/08/2025 02:00:48 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0003 / 0030
# - Training loss:   0.000387
# - Validation loss: 0.000412
# - Epoch took: 0:05:43.480759
# - Time since start: 0:17:36.923765
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\best.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:00:48 AM | engine.py:992 Epoch[3] Complete. Time taken: 00:05:43.481
# 05/08/2025 02:06:13 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:06:26 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.692
# 05/08/2025 02:06:26 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.796
# 05/08/2025 02:06:27 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0004 / 0030
# - Training loss:   0.000395
# - Validation loss: 0.000415
# - Epoch took: 0:05:38.784884
# - Time since start: 0:23:15.709785
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:06:27 AM | engine.py:992 Epoch[4] Complete. Time taken: 00:05:38.787
# 05/08/2025 02:11:45 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:11:59 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.579
# 05/08/2025 02:11:59 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.653
# 05/08/2025 02:11:59 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0005 / 0030
# - Training loss:   0.000376
# - Validation loss: 0.000411
# - Epoch took: 0:05:32.542128
# - Time since start: 0:28:48.252952
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\best.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:11:59 AM | engine.py:992 Epoch[5] Complete. Time taken: 00:05:32.542
# 05/08/2025 02:17:15 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:17:29 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.579
# 05/08/2025 02:17:29 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.674
# 05/08/2025 02:17:29 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0006 / 0030
# - Training loss:   0.000385
# - Validation loss: 0.000402
# - Epoch took: 0:05:29.717772
# - Time since start: 0:34:17.971706
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\best.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:17:29 AM | engine.py:992 Epoch[6] Complete. Time taken: 00:05:29.717
# 05/08/2025 02:22:49 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:23:02 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.581
# 05/08/2025 02:23:02 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.666
# 05/08/2025 02:23:03 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0007 / 0030
# - Training loss:   0.000368
# - Validation loss: 0.000420
# - Epoch took: 0:05:33.615968
# - Time since start: 0:39:51.588502
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:23:03 AM | engine.py:992 Epoch[7] Complete. Time taken: 00:05:33.616
# 05/08/2025 02:28:22 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:28:35 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.601
# 05/08/2025 02:28:35 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.693
# 05/08/2025 02:28:36 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0008 / 0030
# - Training loss:   0.000364
# - Validation loss: 0.000411
# - Epoch took: 0:05:32.943232
# - Time since start: 0:45:24.532474
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:28:36 AM | engine.py:992 Epoch[8] Complete. Time taken: 00:05:32.944
# 05/08/2025 02:33:53 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:34:07 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.284
# 05/08/2025 02:34:07 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.396
# 05/08/2025 02:34:07 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0009 / 0030
# - Training loss:   0.000373
# - Validation loss: 0.000415
# - Epoch took: 0:05:31.456354
# - Time since start: 0:50:55.989698
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:34:07 AM | engine.py:992 Epoch[9] Complete. Time taken: 00:05:31.457
# 05/08/2025 02:39:27 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:39:40 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.416
# 05/08/2025 02:39:40 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.519
# 05/08/2025 02:39:41 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0010 / 0030
# - Training loss:   0.000377
# - Validation loss: 0.000434
# - Epoch took: 0:05:33.432975
# - Time since start: 0:56:29.423576
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:39:41 AM | engine.py:992 Epoch[10] Complete. Time taken: 00:05:33.433
# 05/08/2025 02:44:57 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:45:10 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.359
# 05/08/2025 02:45:10 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.461
# 05/08/2025 02:45:11 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0011 / 0030
# - Training loss:   0.000360
# - Validation loss: 0.000433
# - Epoch took: 0:05:30.162938
# - Time since start: 1:01:59.588607
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:45:11 AM | engine.py:992 Epoch[11] Complete. Time taken: 00:05:30.163
# 05/08/2025 02:50:24 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:50:38 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.460
# 05/08/2025 02:50:38 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.559
# 05/08/2025 02:50:38 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0012 / 0030
# - Training loss:   0.000362
# - Validation loss: 0.000423
# - Epoch took: 0:05:27.179777
# - Time since start: 1:07:26.769877
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:50:38 AM | engine.py:992 Epoch[12] Complete. Time taken: 00:05:27.181
# 05/08/2025 02:55:53 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 02:56:07 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.806
# 05/08/2025 02:56:07 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.890
# 05/08/2025 02:56:08 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0013 / 0030
# - Training loss:   0.000355
# - Validation loss: 0.000421
# - Epoch took: 0:05:29.783898
# - Time since start: 1:12:56.555098
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 02:56:08 AM | engine.py:992 Epoch[13] Complete. Time taken: 00:05:29.784
# 05/08/2025 03:01:25 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:01:38 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.586
# 05/08/2025 03:01:38 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.698
# 05/08/2025 03:01:39 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0014 / 0030
# - Training loss:   0.000354
# - Validation loss: 0.000430
# - Epoch took: 0:05:30.957422
# - Time since start: 1:18:27.513310
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:01:39 AM | engine.py:992 Epoch[14] Complete. Time taken: 00:05:30.958
# 05/08/2025 03:06:56 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:07:09 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.346
# 05/08/2025 03:07:09 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.449
# 05/08/2025 03:07:10 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0015 / 0030
# - Training loss:   0.000353
# - Validation loss: 0.000433
# - Epoch took: 0:05:30.990235
# - Time since start: 1:23:58.504385
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:07:10 AM | engine.py:992 Epoch[15] Complete. Time taken: 00:05:30.991
# 05/08/2025 03:12:30 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:12:44 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.788
# 05/08/2025 03:12:44 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.893
# 05/08/2025 03:12:45 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0016 / 0030
# - Training loss:   0.000355
# - Validation loss: 0.000434
# - Epoch took: 0:05:35.056336
# - Time since start: 1:29:33.561649
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:12:45 AM | engine.py:992 Epoch[16] Complete. Time taken: 00:05:35.056
# 05/08/2025 03:18:00 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:18:14 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.765
# 05/08/2025 03:18:14 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.868
# 05/08/2025 03:18:15 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0017 / 0030
# - Training loss:   0.000350
# - Validation loss: 0.000429
# - Epoch took: 0:05:30.017590
# - Time since start: 1:35:03.580054
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:18:15 AM | engine.py:992 Epoch[17] Complete. Time taken: 00:05:30.019
# 05/08/2025 03:23:29 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:23:44 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:14.406
# 05/08/2025 03:23:44 AM | engine.py:1018 Engine run finished. Time taken: 00:00:14.514
# 05/08/2025 03:23:44 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0018 / 0030
# - Training loss:   0.000342
# - Validation loss: 0.000415
# - Epoch took: 0:05:29.599565
# - Time since start: 1:40:33.181246
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:23:44 AM | engine.py:992 Epoch[18] Complete. Time taken: 00:05:29.600
# 05/08/2025 03:29:02 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:29:16 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.677
# 05/08/2025 03:29:16 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.755
# 05/08/2025 03:29:16 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0019 / 0030
# - Training loss:   0.000357
# - Validation loss: 0.000419
# - Epoch took: 0:05:31.944744
# - Time since start: 1:46:05.126872
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:29:16 AM | engine.py:992 Epoch[19] Complete. Time taken: 00:05:31.945
# 05/08/2025 03:34:35 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:34:48 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.466
# 05/08/2025 03:34:48 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.568
# 05/08/2025 03:34:48 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0020 / 0030
# - Training loss:   0.000350
# - Validation loss: 0.000425
# - Epoch took: 0:05:32.194619
# - Time since start: 1:51:37.322435
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:34:48 AM | engine.py:992 Epoch[20] Complete. Time taken: 00:05:32.196
# 05/08/2025 03:40:05 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:40:18 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.426
# 05/08/2025 03:40:18 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.511
# 05/08/2025 03:40:19 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0021 / 0030
# - Training loss:   0.000352
# - Validation loss: 0.000434
# - Epoch took: 0:05:30.379749
# - Time since start: 1:57:07.703010
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:40:19 AM | engine.py:992 Epoch[21] Complete. Time taken: 00:05:30.381
# 05/08/2025 03:45:32 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:45:46 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.479
# 05/08/2025 03:45:46 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.582
# 05/08/2025 03:45:46 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0022 / 0030
# - Training loss:   0.000347
# - Validation loss: 0.000427
# - Epoch took: 0:05:27.415675
# - Time since start: 2:02:35.119408
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:45:46 AM | engine.py:992 Epoch[22] Complete. Time taken: 00:05:27.416
# 05/08/2025 03:51:05 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:51:19 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.533
# 05/08/2025 03:51:19 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.636
# 05/08/2025 03:51:19 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0023 / 0030
# - Training loss:   0.000364
# - Validation loss: 0.000435
# - Epoch took: 0:05:32.727424
# - Time since start: 2:08:07.847557
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:51:19 AM | engine.py:992 Epoch[23] Complete. Time taken: 00:05:32.728
# 05/08/2025 03:56:34 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 03:56:47 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.579
# 05/08/2025 03:56:47 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.661
# 05/08/2025 03:56:48 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0024 / 0030
# - Training loss:   0.000351
# - Validation loss: 0.000419
# - Epoch took: 0:05:28.675423
# - Time since start: 2:13:36.523878
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 03:56:48 AM | engine.py:992 Epoch[24] Complete. Time taken: 00:05:28.675
# 05/08/2025 04:02:05 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 04:02:19 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.616
# 05/08/2025 04:02:19 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.720
# 05/08/2025 04:02:19 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0025 / 0030
# - Training loss:   0.000343
# - Validation loss: 0.000425
# - Epoch took: 0:05:31.370403
# - Time since start: 2:19:07.895074
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 04:02:19 AM | engine.py:992 Epoch[25] Complete. Time taken: 00:05:31.371
# 05/08/2025 04:07:33 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 04:07:46 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.534
# 05/08/2025 04:07:46 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.629
# 05/08/2025 04:07:47 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0026 / 0030
# - Training loss:   0.000330
# - Validation loss: 0.000424
# - Epoch took: 0:05:27.535456
# - Time since start: 2:24:35.431369
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 04:07:47 AM | engine.py:992 Epoch[26] Complete. Time taken: 00:05:27.536
# 05/08/2025 04:13:00 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 04:13:14 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.454
# 05/08/2025 04:13:14 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.555
# 05/08/2025 04:13:14 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0027 / 0030
# - Training loss:   0.000345
# - Validation loss: 0.000432
# - Epoch took: 0:05:27.799844
# - Time since start: 2:30:03.232136
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 04:13:14 AM | engine.py:992 Epoch[27] Complete. Time taken: 00:05:27.800
# 05/08/2025 04:18:33 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 04:18:47 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.609
# 05/08/2025 04:18:47 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.709
# 05/08/2025 04:18:47 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0028 / 0030
# - Training loss:   0.000351
# - Validation loss: 0.000429
# - Epoch took: 0:05:32.546438
# - Time since start: 2:35:35.779341
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 04:18:47 AM | engine.py:992 Epoch[28] Complete. Time taken: 00:05:32.547
# 05/08/2025 04:23:58 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 04:24:12 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.530
# 05/08/2025 04:24:12 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.645
# 05/08/2025 04:24:12 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0029 / 0030
# - Training loss:   0.000320
# - Validation loss: 0.000441
# - Epoch took: 0:05:25.595632
# - Time since start: 2:41:01.376069
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 04:24:12 AM | engine.py:992 Epoch[29] Complete. Time taken: 00:05:25.597
# 05/08/2025 04:29:32 AM | engine.py:887 Engine run starting with max_epochs=1.
# 05/08/2025 04:29:46 AM | engine.py:992 Epoch[1] Complete. Time taken: 00:00:13.382
# 05/08/2025 04:29:46 AM | engine.py:1018 Engine run finished. Time taken: 00:00:13.462
# 05/08/2025 04:29:46 AM | trainer.py:311
#
# EPOCH SUMMARY
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# - Epoch number: 0030 / 0030
# - Training loss:   0.000330
# - Validation loss: 0.000451
# - Epoch took: 0:05:33.621458
# - Time since start: 2:46:34.998471
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Saving to d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth.
# Output @ d:\src\Piano-Audio-Separation\Model
#
# 05/08/2025 04:29:46 AM | engine.py:992 Epoch[30] Complete. Time taken: 00:05:33.622
# 05/08/2025 04:29:46 AM | engine.py:1018 Engine run finished. Time taken: 02:46:34.999
# State:
# 	iteration: 3000
# 	epoch: 30
# 	epoch_length: 100
# 	max_epochs: 30
# 	output: <class 'dict'>
# 	batch: <class 'dict'>
# 	metrics: <class 'dict'>
# 	dataloader: torch.utils.data.dataloader.DataLoader
# 	seed: <class 'NoneType'>
# 	times: <class 'dict'>
# 	epoch_history: <class 'dict'>
# 	iter_history: <class 'dict'>
# 	past_iter_history: <class 'dict'>
# 	saved_model_path: d:\src\Piano-Audio-Separation\Model\checkpoints\latest.model.pth
# 	output_folder: <class 'pathlib.WindowsPath'>

# %%
separator = nussl.separation.deep.DeepMaskEstimation(
    nussl.AudioSignal(), model_path='checkpoints/best.model.pth',
    device=DEVICE,
)
# Out:
# c:\Users\wallc\.conda\envs\audio_env_TEST\lib\site-packages\nussl\separation\base\separation_base.py:73: UserWarning: input_audio_signal has no data!
#   warnings.warn('input_audio_signal has no data!')
# c:\Users\wallc\.conda\envs\audio_env_TEST\lib\site-packages\nussl\core\audio_signal.py:455: UserWarning: Initializing STFT with data that is non-complex. This might lead to weird results!
#   warnings.warn('Initializing STFT with data that is non-complex. '

# %%
from common import viz

test_folder = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/test"
test_data = data.mixer(stft_params, transform=None, 
    fg_path=test_folder, num_mixtures=MAX_MIXTURES, coherent_prob=1.0)
item = test_data[10]

separator.audio_signal = item['mix']
estimates = separator()
# Since our model only returns one source, let's tack on the
# residual (which should be accompaniment)
estimates.append(item['mix'] - estimates[0])

viz.show_sources(estimates)
# Out:
# <div id=JBBTRNDGOYRVZLUMQSOS class=audio-container preload=auto name=JBBTRNDGOYRVZLUMQSOS><audio name='Source 0' url=data:audio/wav;base64,...></audio><audio name='Source 1' url=data:audio/wav;base64,...></audio></div><style>.inline{display:inline}.center{margin:0 auto}.float-left,.audio-container ul.tracks>li ul,.audio-container .track-name{display:inline;float:left}.float-right{display:inline;float:right}.hidden{display:none}.display-block,.bkg-list li a,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container ul.tracks>li{display:block}.fixed{position:fixed}.relative,.audio-container .main-control,.expandable>:first-child a{position:relative}.absolute,.audio-container .main-control ul,.audio-container .main-control .timebar-wrapper .timebar{position:absolute}.invisible{visibility:hidden}.no-overflow{overflow:hidden}.scroll{overflow:auto;scroll:auto}.inline-block-list,.control-list,.audio-container ul.tracks>li ul,.audio-container .main-control ul{margin:0;padding:0;border:0;overflow:hidden;*zoom:1}.inline-block-list li,.control-list li,.audio-container ul.tracks>li ul li,.audio-container .main-control ul li{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap;padding:0}.inline-block-list-item,.control-list>li,.audio-container ul.tracks>li ul>li,.audio-container .main-control ul>li,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap}@-webkit-keyframes open-sub-expand{0%{opacity:0;max-height:0}100%{opacity:1;max-height:3000px;display:block}}@-moz-keyframes open-sub-expand{from{opacity:0;max-height:0;display:none}to{opacity:1;max-height:3000px;display:block}}@-webkit-keyframes close-sub-expand{0%{opacity:1;max-height:3000px;display:block}100%{opacity:0;max-height:0;display:none}}@-moz-keyframes close-sub-expand{from{opacity:1;max-height:3000px;display:block}to{opacity:0;max-height:0;display:none}}.t-left,.bkg-list li a{text-align:left}.t-right{text-align:right}.t-center{text-align:center;vertical-align:middle}.t-justify{text-align:justify}.t-hide,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container .loader,.audio-container .loading-link,.audio-container .status{text-indent:-3333px;overflow:hidden}.t-caps,.button{text-transform:uppercase}.t-lower{text-transform:lowercase}.t-no-select{-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-o-user-select:none;user-select:none}.no-background{background:none !important}body.high-graphics .css-transition-all,body.high-graphics .bkg-link,body.high-graphics .bkg-list li a,.bkg-list li body.high-graphics a,body.high-graphics .button,body.high-graphics .control-list>li>a,body.high-graphics .audio-container ul.tracks>li ul>li>a,.audio-container ul.tracks>li body.high-graphics ul>li>a,body.high-graphics .audio-container .main-control ul>li>a,.audio-container .main-control body.high-graphics ul>li>a,body.high-graphics .audio-container .tracks,.audio-container body.high-graphics .tracks,body.high-graphics .audio-container .main-control,.audio-container body.high-graphics .main-control,body.high-graphics .audio-container .loading-link,.audio-container body.high-graphics .loading-link,body.high-graphics .basic-expandable .icon-expand,.basic-expandable body.high-graphics .icon-expand,body.high-graphics .expandable .icon-expand,.expandable body.high-graphi ...

# %%
# Run this command to download X 7-second clips from MUSDB18
musdb = nussl.datasets.MUSDB18(download=True)

# %% [markdown]
# # Evaluation

# %%
import json

tfm = nussl_tfm.Compose([
    nussl_tfm.SumSources([['bass', 'drums', 'other']]),
])
test_folder = "D:/src/Piano-Audio-Separation/Dataset/dataset-final/test"
test_dataset = nussl.datasets.MUSDB18(folder=test_folder,subsets=['test'], transform=tfm)
#test_dataset = data.on_the_fly(stft_params, transform=tfm, fg_path=test_folder, num_mixtures=50, coherent_prob=1.0)

# Just do 5 items for speed. Change to 50 for actual experiment.
for i in range(min(50, len(test_dataset))):
    item = test_dataset[i]
    separator.audio_signal = item['mix']
    estimates = separator()

    source_keys = list(item['sources'].keys())
    estimates = {
        'vocals': estimates[0],
        'bass+drums+other': item['mix'] - estimates[0]
    }

    sources = [item['sources'][k] for k in source_keys]
    estimates = [estimates[k] for k in source_keys]

    evaluator = nussl.evaluation.BSSEvalScale(
        sources, estimates, source_labels=source_keys
    )
    scores = evaluator.evaluate()
    output_folder = Path(output_folder).absolute()
    output_folder.mkdir(exist_ok=True)
    output_file = output_folder / sources[0].file_name.replace('wav', 'json')
    with open(output_file, 'w') as f:
        json.dump(scores, f, indent=4)

# %%
import glob
import numpy as np

json_files = glob.glob(f"*.json")
df = nussl.evaluation.aggregate_score_files(
    json_files, aggregator=np.nanmedian)
nussl.evaluation.associate_metrics(separator.model, df, test_dataset)
report_card = nussl.evaluation.report_card(
    df, report_each_source=True)
print(report_card)
# Out:
#
#                         MEAN +/- STD OF METRICS
#
# ┌────────────┬──────────────────┬──────────────────┬──────────────────┐
# │ METRIC     │     OVERALL      │ BASS+DRUMS+OTHER │      VOCALS      │
# ╞════════════╪══════════════════╪══════════════════╪══════════════════╡
# │ #          │       100        │        50        │        50        │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SDR     │   1.82 +/-  5.46 │   5.88 +/-  3.10 │  -2.24 +/-  4.12 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SIR     │   4.42 +/-  5.96 │   8.02 +/-  5.06 │   0.81 +/-  4.43 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SAR     │   6.23 +/-  6.08 │  11.16 +/-  2.37 │   1.30 +/-  4.42 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SD-SDR     │  -0.67 +/-  5.95 │   4.26 +/-  3.02 │  -5.60 +/-  3.55 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SNR        │   4.20 +/-  3.53 │   6.75 +/-  2.12 │   1.66 +/-  2.74 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SRR        │   4.22 +/-  7.43 │  10.58 +/-  4.54 │  -2.13 +/-  2.92 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SDRi    │   1.82 +/-  2.67 │   0.64 +/-  2.65 │   3.00 +/-  2.13 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SD-SDRi    │  -0.66 +/-  3.29 │  -0.97 +/-  3.77 │  -0.35 +/-  2.73 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SNRi       │   4.20 +/-  3.96 │   1.50 +/-  3.33 │   6.91 +/-  2.40 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ MIX-SI-SDR │  -0.00 +/-  6.94 │   5.24 +/-  4.51 │  -5.25 +/-  4.57 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ MIX-SD-SDR │  -0.00 +/-  6.94 │   5.24 +/-  4.51 │  -5.25 +/-  4.57 │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ MIX-SNR    │   0.00 +/-  6.92 │   5.24 +/-  4.50 │  -5.24 +/-  4.50 │
# └────────────┴──────────────────┴──────────────────┴──────────────────┘
#
#                            MEDIAN OF METRICS
#
# ┌────────────┬──────────────────┬──────────────────┬──────────────────┐
# │ METRIC     │     OVERALL      │ BASS+DRUMS+OTHER │      VOCALS      │
# ╞════════════╪══════════════════╪══════════════════╪══════════════════╡
# │ #          │       100        │        50        │        50        │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SDR     │        1.46      │        5.75      │       -0.96      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SIR     │        4.24      │        7.28      │        1.48      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SAR     │        6.78      │       11.00      │        1.96      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SD-SDR     │       -1.38      │        4.37      │       -4.71      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SNR        │        3.69      │        6.66      │        2.47      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SRR        │        1.96      │        9.20      │       -1.63      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SI-SDRi    │        1.78      │        1.13      │        3.04      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SD-SDRi    │       -0.20      │       -0.14      │       -0.77      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ SNRi       │        3.66      │        2.45      │        6.68      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ MIX-SI-SDR │       -0.07      │        4.47      │       -4.57      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ MIX-SD-SDR │       -0.07      │        4.47      │       -4.57      │
# ├────────────┼──────────────────┼──────────────────┼──────────────────┤
# │ MIX-SNR    │        0.00      │        4.50      │       -4.50      │
# └────────────┴──────────────────┴──────────────────┴──────────────────┘

# %%
separator.model.save('checkpoints/best.model.pth')
# Out:
# 'checkpoints/best.model.pth'

# %%
model_checkpoint = torch.load('checkpoints/best.model.pth')

# %%
model_checkpoint['metadata'].keys()
